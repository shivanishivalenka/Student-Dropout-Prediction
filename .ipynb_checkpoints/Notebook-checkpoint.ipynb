# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./dataset.csv')
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                              1                       1            1
# ...

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %%
df["Gender"].describe()
# Out:
# count    4424.000000
# mean        0.351718
# std         0.477560
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Gender, dtype: float64

# %%
df.isna().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# ...

# %%
df.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# Tuition fees up to date                             int64
# Gender                                              int64
# ...

# %%
df['Target'] = df['Target'].map({'Dropout':0,'Graduate':1,'Enrolled':2})

# %%
df.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# Tuition fees up to date                             int64
# Gender                                              int64
# ...

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
df.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 4419                           1                       1            1
# 4420                           1                       1           19
# 4421                           1                       1            1
# 4422                           1                       1            1
# 4423                           1                       1            9
#
#       Mother's qualification  Father's qualification  Mother's occupation  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for ever in df.columns:
    print(ever+':')
    print(df[ever].corr(df['Target']))
# Out:
# Marital status:
# -0.07430980474828737
# Application mode:
# -0.11008601130826387
# Application order:
# 0.02739262156723137
# Course:
# -0.009877475210118641
# Daytime/evening attendance:
# 0.06643892126881237
# Previous qualification:
# -0.06802127880794245
# Nacionality:
# 0.009247826022182548
# Mother's qualification:
# -0.07110042591922107
# Father's qualification:
# -0.033291123810334174
# Mother's occupation:
# 0.07759339222631637
# Father's occupation:
# 0.0949155794947105
# Displaced:
# 0.070649099793173
# Educational special needs:
# 0.003751126199791949
# Debtor:
# -0.15480160305546917
# Tuition fees up to date:
# 0.34212054744896725
# Gender:
# -0.11845383406768115
# Scholarship holder:
# 0.11451663688839826
# Age at enrollment:
# -0.20180618945687467
# International:
# 0.015893341271952976
# Curricular units 1st sem (credited):
# -0.0024639396702293053
# Curricular units 1st sem (enrolled):
# 0.052020083961248756
# Curricular units 1st sem (evaluations):
# ...

# %% [markdown]
# Based on the magnitudes of the correlation coefficients, we can categorize them into different levels of correlation strength. Here's a common categorization:
#
# - **Very Weak (|\(r\)| < 0.10):**
#   - Course (0.01)
#   - Nationality (-0.00)
#   - Father's qualification (0.00)
#   - International (0.00)
#   - Educational special needs (-0.01)
#   - Unemployment rate (0.01)
#   - Inflation rate (-0.03)
#   - Mother's qualification (-0.04)
#
# - **Weak (0.10 ≤ |\(r\)| < 0.30):**
#   - Application order (0.09)
#   - Marital status (-0.09)
#   - Mother's occupation (0.05)
#   - Father's occupation (0.05)
#   - Curricular units 1st sem (evaluations) (0.04)
#   - Curricular units 1st sem (credited) (0.05)
#   - Curricular units 2nd sem (credited) (0.05)
#   - Curricular units 2nd sem (evaluations) (0.09)
#   - Mother's qualification (-0.04)
#
# - **Moderate (0.30 ≤ |\(r\)| < 0.50):**
#   - Age at enrollment (-0.24)
#   - Scholarship holder (0.30)
#   - Gender (-0.23)
#   - Displaced (0.11)
#   - Tuition fees up to date (0.41)
#   - GDP (0.04)
#
# - **Strong (0.50 ≤ |\(r\)| < 0.70):**
#   - Curricular units 1st sem (grade) (0.49)
#   - Curricular units 2nd sem (grade) (0.57)
#
# - **Very Strong (|\(r\)| ≥ 0.70):**
#   - Curricular units 1st sem (approved) (0.53)
#   - Curricular units 2nd sem (approved) (0.62)
#
# - **Extreme (|\(r\)| = 1.00):**
#   - No extreme correlations are present in the given values.

# %% [markdown]
# Let us consider only moderate and strong and very strong correlated columns as features-
#
# - **Moderate (0.30 ≤ |\(r\)| < 0.50):**
#   - Age at enrollment (-0.24)
#   - Scholarship holder (0.30)
#   - Gender (-0.23)
#   - Displaced (0.11)
#   - Tuition fees up to date (0.41)
#   - GDP (0.04)
#
# - **Strong (0.50 ≤ |\(r\)| < 0.70):**
#   - Curricular units 1st sem (grade) (0.49)
#   - Curricular units 2nd sem (grade) (0.57)
#
# - **Very Strong (|\(r\)| ≥ 0.70):**
#   - Curricular units 1st sem (approved) (0.53)
#   - Curricular units 2nd sem (approved) (0.62)

# %%
features = ['Age at enrollment','Scholarship holder','Gender','Displaced','Tuition fees up to date','GDP','Curricular units 1st sem (grade)'
           ,'Curricular units 2nd sem (grade)','Curricular units 1st sem (approved)','Curricular units 2nd sem (approved)']
len(features),features
# Out:
# (10,
#  ['Age at enrollment',
#   'Scholarship holder',
#   'Gender',
#   'Displaced',
#   'Tuition fees up to date',
#   'GDP',
#   'Curricular units 1st sem (grade)',
#   'Curricular units 2nd sem (grade)',
#   'Curricular units 1st sem (approved)',
#   'Curricular units 2nd sem (approved)'])

# %%
for ever in features:
    sns.boxplot(df[ever])
    plt.title(ever)
    plt.show()

# %%
#trimming outliers
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_fence = Q1 - 1.5 * IQR
    upper_fence = Q3 + 1.5 * IQR
    
    # Filter the DataFrame to exclude outliers
    filtered_data = data[(data[column] >= lower_fence) & (data[column] <= upper_fence)]
    
    return filtered_data

outlier_features= ['Age at enrollment',
  'Scholarship holder',
  'Curricular units 1st sem (grade)',
  'Curricular units 2nd sem (grade)',
  'Curricular units 1st sem (approved)',
  'Curricular units 2nd sem (approved)']
# Iterate over the specified columns and remove outliers
for column in outlier_features:
    df = remove_outliers_iqr(df, column)

# %%
for ever in outlier_features:
    print(ever)
    sns.boxplot(df[ever].values)
    
    plt.title(ever)
    plt.show()
# Out:
# Age at enrollment
# Scholarship holder
# Curricular units 1st sem (grade)
# Curricular units 2nd sem (grade)
# Curricular units 1st sem (approved)
# Curricular units 2nd sem (approved)

# %%
import pandas as pd

outlier_threshold = 1.5
def cap_outliers(df, feature, threshold):
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_fence = Q1 - threshold * IQR
    upper_fence = Q3 + threshold * IQR
    
    # Cap extreme values
    df[feature] = df[feature].clip(lower=lower_fence, upper=upper_fence)
    
    return df
clip_outlier_features = ['Age at enrollment',
  'Curricular units 1st sem (grade)',
  'Curricular units 2nd sem (grade)']
# Iterate over the outlier_features and cap outliers
for feature in clip_outlier_features:
    df = cap_outliers(df, feature, outlier_threshold)

# %%
for ever in outlier_features:
    print(ever)
    sns.boxplot(df[ever].values)
    
    plt.title(ever)
    plt.show()
# Out:
# Age at enrollment
# Scholarship holder
# Curricular units 1st sem (grade)
# Curricular units 2nd sem (grade)
# Curricular units 1st sem (approved)
# Curricular units 2nd sem (approved)

# %%
sns.histplot(df['Age at enrollment'])
plt.show()
labels = ['Yes','No']
plt.pie(df["Scholarship holder"].value_counts(),labels = labels, autopct='%1.1f%%',startangle=90)
plt.title("Scholarship holder")
plt.show()
Labels = ["Male","Female"]
plt.pie(df["Gender"].value_counts(),labels = Labels, autopct='%1.1f%%',startangle=90)
plt.title("Gender")
plt.show()

# %%
labels = ['Yes','No']
plt.pie(df["Displaced"].value_counts(),labels = labels, autopct='%1.1f%%',startangle=90)
plt.title("Displaced")
# Out:
# Text(0.5, 1.0, 'Displaced')

# %%
labels = ['Yes','No']
plt.pie(df["Tuition fees up to date"].value_counts(),labels = labels, autopct='%1.1f%%',startangle=90)
plt.title("Tuition fees up to date")
# Out:
# Text(0.5, 1.0, 'Tuition fees up to date')

# %%
sns.histplot(df['GDP'])
plt.show()

# %%
features = ['Age at enrollment','Scholarship holder','Gender','Displaced','Tuition fees up to date','GDP','Curricular units 1st sem (grade)'
           ,'Curricular units 2nd sem (grade)','Curricular units 1st sem (approved)','Curricular units 2nd sem (approved)']

# %%
sns.histplot(df['Curricular units 1st sem (grade)'])
plt.title('Curricular units 1st sem (grade)')
plt.show()
sns.histplot(df['Curricular units 2nd sem (grade)'])
plt.title('Curricular units 2nd sem (grade)')
plt.show()
sns.histplot(df['Curricular units 1st sem (approved)'])
plt.title('Curricular units 1st sem (approved)')
plt.show()
sns.histplot(df['Curricular units 2nd sem (approved)'])
plt.title('Curricular units 2nd sem (approved)')
plt.show()

# %%
df1 = df[['Age at enrollment','Scholarship holder','Gender','Displaced','Tuition fees up to date','GDP','Curricular units 1st sem (grade)'
           ,'Curricular units 2nd sem (grade)','Curricular units 1st sem (approved)','Curricular units 2nd sem (approved)']]
df1
# Out:
#       Age at enrollment  Scholarship holder  Gender  Displaced  \
# 1                  19.0                   0       1          1
# 3                  20.0                   0       0          1
# 8                  21.0                   1       0          0
# 10                 18.0                   0       0          1
# 11                 18.0                   1       0          1
# ...                 ...                 ...     ...        ...
# 4417               20.0                   1       0          1
# 4418               20.0                   0       1          0
# 4419               19.0                   0       1          0
# 4422               20.0                   1       0          1
# 4423               22.0                   0       0          1
#
#       Tuition fees up to date   GDP  Curricular units 1st sem (grade)  \
# 1                           0  0.79                         14.000000
# ...

# %%
#Correlation heatmap
heatmap = sns.heatmap(df1.corr())
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
plt.pie(df["Target"].value_counts(),labels = ['Graduate','Dropout','Enrolled'],autopct='%1.1f%%')
plt.title("Target")
plt.show()

# %% [markdown]
# # Prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
scaler=StandardScaler()
df=df[df.Target!=2]
df["Target"].describe()
df1 = df[['Age at enrollment','Scholarship holder','Gender','Displaced','Tuition fees up to date','GDP','Curricular units 1st sem (grade)'
           ,'Curricular units 2nd sem (grade)','Curricular units 1st sem (approved)','Curricular units 2nd sem (approved)']]

# %%
X = df1
y = df["Target"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size= 0.2, random_state = 4)
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)
#({'Dropout':0,'Enrolled':1,'Graduate':2})

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{conf_matrix}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.8950437317784257
# Confusion Matrix:
# [[ 15  32]
#  [  4 292]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.32      0.45        47
#            1       0.90      0.99      0.94       296
#
#     accuracy                           0.90       343
#    macro avg       0.85      0.65      0.70       343
# weighted avg       0.89      0.90      0.88       343

# %%
from sklearn.ensemble import RandomForestClassifier 
model1 = RandomForestClassifier()
model1.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred1 = model1.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred1)
conf_matrix = confusion_matrix(y_test, y_pred1)
classification_rep = classification_report(y_test, y_pred1)

print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{conf_matrix}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.892128279883382
# Confusion Matrix:
# [[ 16  31]
#  [  6 290]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.34      0.46        47
#            1       0.90      0.98      0.94       296
#
#     accuracy                           0.89       343
#    macro avg       0.82      0.66      0.70       343
# weighted avg       0.88      0.89      0.87       343

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred2 = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred2)
conf_matrix = confusion_matrix(y_test, y_pred2)
classification_rep = classification_report(y_test, y_pred1)

print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{conf_matrix}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.8979591836734694
# Confusion Matrix:
# [[ 15  32]
#  [  3 293]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.34      0.46        47
#            1       0.90      0.98      0.94       296
#
#     accuracy                           0.89       343
#    macro avg       0.82      0.66      0.70       343
# weighted avg       0.88      0.89      0.87       343
